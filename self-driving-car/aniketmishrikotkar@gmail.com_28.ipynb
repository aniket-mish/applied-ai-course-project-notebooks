# %% [markdown]
# <h1>End to End Learning for Self-Driving Cars</h1>
#
# <h4>This is a tensorFlow implementation of a Nvidia research paper with some changes by Sully Chen</h4>

# %%
# Credits: https://github.com/SullyChen/Autopilot-TensorFlow
# Research paper: End to End Learning for Self-Driving Cars by Nvidia. [https://arxiv.org/pdf/1604.07316.pdf]

# NVidia dataset: 72 hrs of video => 72*60*60*30 = 7,776,000 images
# Nvidia blog: https://devblogs.nvidia.com/deep-learning-self-driving-cars/

# Our Dataset: https://github.com/SullyChen/Autopilot-TensorFlow [https://drive.google.com/file/d/0B-KJCaaF7elleG1RbzVPZWV4Tlk/view]
# Size: 25 minutes = 25*60*30 = 45,000 images ~ 2.3 GB

# If you want to try on a slightly large dataset: 70 minutes of data ~ 223GB
# Refer: https://medium.com/udacity/open-sourcing-223gb-of-mountain-view-driving-data-f6b5593fbfa5
# Format: Image, latitude, longitude, gear, brake, throttle, steering angles and speed

# Additional Installations:
# pip3 install h5py


# AWS: https://aws.amazon.com/blogs/machine-learning/get-started-with-deep-learning-using-the-aws-deep-learning-ami/

# Youtube:https://www.youtube.com/watch?v=qhUvQiKec2U
# Further reading and extensions: https://medium.com/udacity/teaching-a-machine-to-steer-a-car-d73217f2492c
# More data: https://medium.com/udacity/open-sourcing-223gb-of-mountain-view-driving-data-f6b5593fbfa5

# %% [markdown]
# <h2>Reading images, Splitting data(70:30) and Creating batches for training</h2>

# %%
import cv2
import random
import numpy as np

xs = []
ys = []

#points to the end of the last batch
train_batch_pointer = 0
val_batch_pointer = 0

#read data.txt
with open("driving_dataset/data.txt") as f:
    for line in f:
        xs.append("driving_dataset/" + line.split()[0])
        #the paper by Nvidia uses the inverse of the turning radius,
        #but steering wheel angle is proportional to the inverse of turning radius
        #so the steering wheel angle in radians is used as the output
        ys.append(float(line.split()[1]) * 3.14159265 / 180)

#get number of images
num_images = len(xs)

#shuffle list of images
c = list(zip(xs, ys))
random.shuffle(c)
xs, ys = zip(*c)

train_xs = xs[:int(len(xs) * 0.7)]
train_ys = ys[:int(len(xs) * 0.7)]

val_xs = xs[-int(len(xs) * 0.3):]
val_ys = ys[-int(len(xs) * 0.3):]

num_train_images = len(train_xs)
num_val_images = len(val_xs)

def LoadTrainBatch(batch_size):
    global train_batch_pointer
    x_out = []
    y_out = []
    for i in range(0, batch_size):
        x_out.append(cv2.resize(cv2.imread(train_xs[(train_batch_pointer + i) % num_train_images])[-150:], (200, 66)) / 255.0)
        y_out.append([train_ys[(train_batch_pointer + i) % num_train_images]])
    train_batch_pointer += batch_size
    return x_out, y_out

def LoadValBatch(batch_size):
    global val_batch_pointer
    x_out = []
    y_out = []
    for i in range(0, batch_size):
        x_out.append(cv2.resize(cv2.imread(val_xs[(val_batch_pointer + i) % num_val_images])[-150:], (200, 66)) / 255.0)
        y_out.append([val_ys[(val_batch_pointer + i) % num_val_images]])
    val_batch_pointer += batch_size
    return x_out, y_out

# %%
import matplotlib.pyplot as plt

plt.hist(train_ys, bins = 50, histtype = "step")
plt.hist(val_ys, bins = 50, histtype = "step")
plt.title("Steering Wheel angle in train and val")
plt.xlabel("Angle")
plt.ylabel("Bin count")
plt.show()

# %% [markdown]
# <h2>Model Architecture</h2>

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import scipy

def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W, stride):
  return tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding='VALID')

x = tf.placeholder(tf.float32, shape=[None, 66, 200, 3])
y_ = tf.placeholder(tf.float32, shape=[None, 1])

x_image = x

#first convolutional layer
W_conv1 = weight_variable([5, 5, 3, 24])
b_conv1 = bias_variable([24])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1, 2) + b_conv1)

#second convolutional layer
W_conv2 = weight_variable([5, 5, 24, 36])
b_conv2 = bias_variable([36])

h_conv2 = tf.nn.relu(conv2d(h_conv1, W_conv2, 2) + b_conv2)

#third convolutional layer
W_conv3 = weight_variable([5, 5, 36, 48])
b_conv3 = bias_variable([48])

h_conv3 = tf.nn.relu(conv2d(h_conv2, W_conv3, 2) + b_conv3)

#fourth convolutional layer
W_conv4 = weight_variable([3, 3, 48, 64])
b_conv4 = bias_variable([64])

h_conv4 = tf.nn.relu(conv2d(h_conv3, W_conv4, 1) + b_conv4)

#fifth convolutional layer
W_conv5 = weight_variable([3, 3, 64, 64])
b_conv5 = bias_variable([64])

h_conv5 = tf.nn.relu(conv2d(h_conv4, W_conv5, 1) + b_conv5)

#FCL 1
W_fc1 = weight_variable([1152, 1164])
b_fc1 = bias_variable([1164])

h_conv5_flat = tf.reshape(h_conv5, [-1, 1152])
h_fc1 = tf.nn.relu(tf.matmul(h_conv5_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

#FCL 2
W_fc2 = weight_variable([1164, 100])
b_fc2 = bias_variable([100])

h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)

#FCL 3
W_fc3 = weight_variable([100, 50])
b_fc3 = bias_variable([50])

h_fc3 = tf.nn.relu(tf.matmul(h_fc2_drop, W_fc3) + b_fc3)

h_fc3_drop = tf.nn.dropout(h_fc3, keep_prob)

#FCL 3
W_fc4 = weight_variable([50, 10])
b_fc4 = bias_variable([10])

h_fc4 = tf.nn.relu(tf.matmul(h_fc3_drop, W_fc4) + b_fc4)

h_fc4_drop = tf.nn.dropout(h_fc4, keep_prob)

#Output
W_fc5 = weight_variable([10, 1])
b_fc5 = bias_variable([1])

y = tf.multiply((tf.matmul(h_fc4_drop, W_fc5) + b_fc5), 2)
# Out:
# WARNING:tensorflow:From C:\Users\Aniket\AppliedAI\Anaconda3\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From <ipython-input-5-9c27fa00abb1>:59: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# <h2>Training the model</h2>
#
# <h4>To visualize training using Tensorboard use tensorboard --logdir=./logs, then open http://0.0.0.0:6006/ into your web browser.</h4>

# %%
import os
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from tensorflow.core.protobuf import saver_pb2

LOGDIR = './save'

sess = tf.InteractiveSession()

L2NormConst = 0.001

train_vars = tf.trainable_variables()

loss = tf.reduce_mean(tf.square(tf.subtract(y_, y))) + tf.add_n([tf.nn.l2_loss(v) for v in train_vars]) * L2NormConst
train_step = tf.train.AdamOptimizer(0.0001).minimize(loss)

sess.run(tf.global_variables_initializer())

# create a summary to monitor cost tensor
tf.summary.scalar("loss", loss)

# merge all summaries into a single op
merged_summary_op =  tf.summary.merge_all()

saver = tf.train.Saver()

# op to write logs to Tensorboard
logs_path = './logs'
summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())

epochs = 30
batch_size = 100

# train over the dataset about 30 times
previous_i = 0
previous_loss = 0
for epoch in range(epochs):
    for i in range(int(num_images/batch_size)):        
        xs, ys = LoadTrainBatch(batch_size)
        train_step.run(feed_dict={x: xs, y_: ys, keep_prob: 0.5})
        if i % 10 == 0:            
            xs, ys = LoadValBatch(batch_size)
            loss_value = loss.eval(feed_dict={x: xs, y_: ys, keep_prob: 1.0})
            print("Epoch: %d, Step: %d, Loss: %g" % (epoch, epoch * batch_size + i, loss_value))

        # write logs at every iteration
        summary = merged_summary_op.eval(feed_dict={x: xs, y_: ys, keep_prob: 1.0})
        summary_writer.add_summary(summary, epoch * num_images/batch_size + i)

        if i % batch_size == 0:
            if not os.path.exists(LOGDIR):
                os.makedirs(LOGDIR)            
            checkpoint_path = os.path.join(LOGDIR, "model_.ckpt")
            filename = saver.save(sess, checkpoint_path)
    print("Model saved in file: %s" % filename)

print("Run the command line:\n" \
          "--> tensorboard --logdir=./logs " \
          "\nThen open http://0.0.0.0:6006/ into your web browser")

sess.close()
# Out:
# Epoch: 0, Step: 0, Loss: 7.67311
# Epoch: 0, Step: 10, Loss: 6.28109
# Epoch: 0, Step: 20, Loss: 6.27818
# Epoch: 0, Step: 30, Loss: 6.52348
# Epoch: 0, Step: 40, Loss: 6.3585
# Epoch: 0, Step: 50, Loss: 6.1843
# Epoch: 0, Step: 60, Loss: 6.30853
# Epoch: 0, Step: 70, Loss: 6.03263
# Epoch: 0, Step: 80, Loss: 6.78401
# Epoch: 0, Step: 90, Loss: 5.99166
# Epoch: 0, Step: 100, Loss: 6.04139
# Epoch: 0, Step: 110, Loss: 6.06215
# Epoch: 0, Step: 120, Loss: 5.94563
# Epoch: 0, Step: 130, Loss: 6.03258
# Epoch: 0, Step: 140, Loss: 5.93112
# Epoch: 0, Step: 150, Loss: 5.90773
# Epoch: 0, Step: 160, Loss: 5.89275
# Epoch: 0, Step: 170, Loss: 6.46352
# Epoch: 0, Step: 180, Loss: 5.82709
# Epoch: 0, Step: 190, Loss: 5.85735
# Epoch: 0, Step: 200, Loss: 5.70376
# Epoch: 0, Step: 210, Loss: 5.70414
# Epoch: 0, Step: 220, Loss: 5.67082
# Epoch: 0, Step: 230, Loss: 5.70979
# Epoch: 0, Step: 240, Loss: 5.81898
# Epoch: 0, Step: 250, Loss: 5.58706
# Epoch: 0, Step: 260, Loss: 5.77134
# Epoch: 0, Step: 270, Loss: 5.47172
# Epoch: 0, Step: 280, Loss: 5.57277
# Epoch: 0, Step: 290, Loss: 5.54018
# Epoch: 0, Step: 300, Loss: 5.74017
# Epoch: 0, Step: 310, Loss: 5.47728
# Epoch: 0, Step: 320, Loss: 5.37401
# Epoch: 0, Step: 330, Loss: 5.47368
# Epoch: 0, Step: 340, Loss: 5.48226
# Epoch: 0, Step: 350, Loss: 5.53425
# Epoch: 0, Step: 360, Loss: 5.31463
# Epoch: 0, Step: 370, Loss: 5.42116
# Epoch: 0, Step: 380, Loss: 5.19903
# Epoch: 0, Step: 390, Loss: 5.38031
# Epoch: 0, Step: 400, Loss: 5.30893
# Epoch: 0, Step: 410, Loss: 5.38509
# Epoch: 0, Step: 420, Loss: 5.3605
# Epoch: 0, Step: 430, Loss: 5.1413
# Epoch: 0, Step: 440, Loss: 5.15616
# Epoch: 0, Step: 450, Loss: 5.19203
# Model saved in file: ./save\model_.ckpt
# Epoch: 1, Step: 100, Loss: 5.11829
# Epoch: 1, Step: 110, Loss: 5.10727
# Epoch: 1, Step: 120, Loss: 5.10962
# Epoch: 1, Step: 130, Loss: 5.0169
# Epoch: 1, Step: 140, Loss: 5.19279
# Epoch: 1, Step: 150, Loss: 4.97527
# Epoch: 1, Step: 160, Loss: 5.36741
# Epoch: 1, Step: 170, Loss: 4.99294
# Epoch: 1, Step: 180, Loss: 5.65773
# Epoch: 1, Step: 190, Loss: 5.25573
# Epoch: 1, Step: 200, Loss: 5.47993
# Epoch: 1, Step: 210, Loss: 4.95483
# Epoch: 1, Step: 220, Loss: 4.90539
# Epoch: 1, Step: 230, Loss: 4.94793
# Epoch: 1, Step: 240, Loss: 4.93226
# Epoch: 1, Step: 250, Loss: 4.93773
# Epoch: 1, Step: 260, Loss: 4.94375
# Epoch: 1, Step: 270, Loss: 4.89225
# Epoch: 1, Step: 280, Loss: 4.82864
# Epoch: 1, Step: 290, Loss: 4.81742
# Epoch: 1, Step: 300, Loss: 5.06759
# Epoch: 1, Step: 310, Loss: 4.77985
# Epoch: 1, Step: 320, Loss: 4.87335
# Epoch: 1, Step: 330, Loss: 4.6265
# Epoch: 1, Step: 340, Loss: 4.71464
# Epoch: 1, Step: 350, Loss: 4.8852
# Epoch: 1, Step: 360, Loss: 4.67058
# Epoch: 1, Step: 370, Loss: 4.72633
# Epoch: 1, Step: 380, Loss: 4.69467
# Epoch: 1, Step: 390, Loss: 4.79701
# Epoch: 1, Step: 400, Loss: 4.69444
# Epoch: 1, Step: 410, Loss: 4.57541
# Epoch: 1, Step: 420, Loss: 4.68964
# Epoch: 1, Step: 430, Loss: 4.53756
# Epoch: 1, Step: 440, Loss: 4.51814
# Epoch: 1, Step: 450, Loss: 4.68932
# Epoch: 1, Step: 460, Loss: 4.52177
# Epoch: 1, Step: 470, Loss: 4.56936
# Epoch: 1, Step: 480, Loss: 4.53116
# Epoch: 1, Step: 490, Loss: 4.6958
# Epoch: 1, Step: 500, Loss: 4.4194
# Epoch: 1, Step: 510, Loss: 4.52657
# Epoch: 1, Step: 520, Loss: 4.62287
# Epoch: 1, Step: 530, Loss: 4.57169
# Epoch: 1, Step: 540, Loss: 4.40598
# Epoch: 1, Step: 550, Loss: 4.34757
# Model saved in file: ./save\model_.ckpt
# Epoch: 2, Step: 200, Loss: 4.32091
# Epoch: 2, Step: 210, Loss: 4.4479
# Epoch: 2, Step: 220, Loss: 4.60001
# Epoch: 2, Step: 230, Loss: 4.37637
# Epoch: 2, Step: 240, Loss: 4.4711
# Epoch: 2, Step: 250, Loss: 4.31022
# Epoch: 2, Step: 260, Loss: 4.44021
# Epoch: 2, Step: 270, Loss: 4.34348
# Epoch: 2, Step: 280, Loss: 4.30325
# Epoch: 2, Step: 290, Loss: 4.19841
# Epoch: 2, Step: 300, Loss: 4.22711
# Epoch: 2, Step: 310, Loss: 4.22997
# Epoch: 2, Step: 320, Loss: 4.59957
# Epoch: 2, Step: 330, Loss: 4.38437
# Epoch: 2, Step: 340, Loss: 4.16994
# Epoch: 2, Step: 350, Loss: 4.33578
# Epoch: 2, Step: 360, Loss: 4.06852
# Epoch: 2, Step: 370, Loss: 4.14995
# Epoch: 2, Step: 380, Loss: 4.22076
# Epoch: 2, Step: 390, Loss: 4.36497
# Epoch: 2, Step: 400, Loss: 4.05025
# Epoch: 2, Step: 410, Loss: 4.26451
# Epoch: 2, Step: 420, Loss: 4.06359
# Epoch: 2, Step: 430, Loss: 3.92489
# Epoch: 2, Step: 440, Loss: 4.20453
# Epoch: 2, Step: 450, Loss: 4.05396
# Epoch: 2, Step: 460, Loss: 4.08514
# Epoch: 2, Step: 470, Loss: 4.69506
# Epoch: 2, Step: 480, Loss: 4.17572
# Epoch: 2, Step: 490, Loss: 4.12152
# Epoch: 2, Step: 500, Loss: 4.09936
# Epoch: 2, Step: 510, Loss: 4.02746
# Epoch: 2, Step: 520, Loss: 4.00337
# Epoch: 2, Step: 530, Loss: 3.86666
# Epoch: 2, Step: 540, Loss: 3.89566
# Epoch: 2, Step: 550, Loss: 3.91453
# Epoch: 2, Step: 560, Loss: 4.08175
# Epoch: 2, Step: 570, Loss: 3.8654
# Epoch: 2, Step: 580, Loss: 3.96151
# Epoch: 2, Step: 590, Loss: 3.82843
# Epoch: 2, Step: 600, Loss: 4.2684
# Epoch: 2, Step: 610, Loss: 4.03023
# Epoch: 2, Step: 620, Loss: 3.93511
# Epoch: 2, Step: 630, Loss: 3.76518
# Epoch: 2, Step: 640, Loss: 3.8572
# Epoch: 2, Step: 650, Loss: 3.71778
# Model saved in file: ./save\model_.ckpt
# Epoch: 3, Step: 300, Loss: 3.82238
# Epoch: 3, Step: 310, Loss: 3.90518
# Epoch: 3, Step: 320, Loss: 4.10329
# Epoch: 3, Step: 330, Loss: 3.76144
# Epoch: 3, Step: 340, Loss: 3.84278
# Epoch: 3, Step: 350, Loss: 3.73763
# Epoch: 3, Step: 360, Loss: 3.77909
# Epoch: 3, Step: 370, Loss: 4.40183
# Epoch: 3, Step: 380, Loss: 3.6206
# Epoch: 3, Step: 390, Loss: 3.85742
# Epoch: 3, Step: 400, Loss: 3.75104
# Epoch: 3, Step: 410, Loss: 3.82133
# Epoch: 3, Step: 420, Loss: 3.59166
# Epoch: 3, Step: 430, Loss: 3.77623
# Epoch: 3, Step: 440, Loss: 3.76702
# Epoch: 3, Step: 450, Loss: 3.77453
# Epoch: 3, Step: 460, Loss: 4.26092
# Epoch: 3, Step: 470, Loss: 3.74569
# Epoch: 3, Step: 480, Loss: 3.54619
# Epoch: 3, Step: 490, Loss: 3.66247
# Epoch: 3, Step: 500, Loss: 3.5524
# Epoch: 3, Step: 510, Loss: 3.64254
# Epoch: 3, Step: 520, Loss: 3.83122
# Epoch: 3, Step: 530, Loss: 3.55797
# Epoch: 3, Step: 540, Loss: 3.63409
# Epoch: 3, Step: 550, Loss: 3.605
# Epoch: 3, Step: 560, Loss: 3.57723
# Epoch: 3, Step: 570, Loss: 3.49719
# Epoch: 3, Step: 580, Loss: 3.86233
# Epoch: 3, Step: 590, Loss: 3.52442
# Epoch: 3, Step: 600, Loss: 3.49292
# Epoch: 3, Step: 610, Loss: 3.5087
# Epoch: 3, Step: 620, Loss: 3.59176
# Epoch: 3, Step: 630, Loss: 3.67119
# Epoch: 3, Step: 640, Loss: 3.49585
# Epoch: 3, Step: 650, Loss: 3.57399
# Epoch: 3, Step: 660, Loss: 3.36566
# Epoch: 3, Step: 670, Loss: 3.56142
# Epoch: 3, Step: 680, Loss: 3.45687
# Epoch: 3, Step: 690, Loss: 3.6297
# Epoch: 3, Step: 700, Loss: 3.60588
# Epoch: 3, Step: 710, Loss: 3.357
# Epoch: 3, Step: 720, Loss: 3.36817
# Epoch: 3, Step: 730, Loss: 3.40445
# Epoch: 3, Step: 740, Loss: 3.4211
# Epoch: 3, Step: 750, Loss: 3.36846
# Model saved in file: ./save\model_.ckpt
# Epoch: 4, Step: 400, Loss: 3.39852
# Epoch: 4, Step: 410, Loss: 3.28658
# Epoch: 4, Step: 420, Loss: 3.49927
# Epoch: 4, Step: 430, Loss: 3.24628
# Epoch: 4, Step: 440, Loss: 3.66479
# Epoch: 4, Step: 450, Loss: 3.33706
# Epoch: 4, Step: 460, Loss: 4.07086
# Epoch: 4, Step: 470, Loss: 3.64449
# Epoch: 4, Step: 480, Loss: 3.69275
# Epoch: 4, Step: 490, Loss: 3.51401
# Epoch: 4, Step: 500, Loss: 3.24797
# Epoch: 4, Step: 510, Loss: 3.41067
# Epoch: 4, Step: 520, Loss: 3.22562
# Epoch: 4, Step: 530, Loss: 3.40643
# Epoch: 4, Step: 540, Loss: 3.4377
# Epoch: 4, Step: 550, Loss: 3.22327
# Epoch: 4, Step: 560, Loss: 3.4039
# Epoch: 4, Step: 570, Loss: 3.29132
# Epoch: 4, Step: 580, Loss: 3.44061
# Epoch: 4, Step: 590, Loss: 3.35988
# Epoch: 4, Step: 600, Loss: 3.35127
# Epoch: 4, Step: 610, Loss: 3.17167
# Epoch: 4, Step: 620, Loss: 3.17715
# Epoch: 4, Step: 630, Loss: 3.37815
# Epoch: 4, Step: 640, Loss: 3.3074
# Epoch: 4, Step: 650, Loss: 3.28209
# Epoch: 4, Step: 660, Loss: 3.25929
# Epoch: 4, Step: 670, Loss: 3.34852
# Epoch: 4, Step: 680, Loss: 3.24169
# Epoch: 4, Step: 690, Loss: 3.18827
# Epoch: 4, Step: 700, Loss: 3.26915
# Epoch: 4, Step: 710, Loss: 3.11879
# Epoch: 4, Step: 720, Loss: 3.14799
# Epoch: 4, Step: 730, Loss: 3.19855
# Epoch: 4, Step: 740, Loss: 3.20225
# Epoch: 4, Step: 750, Loss: 3.25293
# Epoch: 4, Step: 760, Loss: 3.15441
# Epoch: 4, Step: 770, Loss: 3.26031
# Epoch: 4, Step: 780, Loss: 3.13215
# Epoch: 4, Step: 790, Loss: 3.20475
# Epoch: 4, Step: 800, Loss: 3.14789
# Epoch: 4, Step: 810, Loss: 3.41228
# Epoch: 4, Step: 820, Loss: 3.08741
# Epoch: 4, Step: 830, Loss: 3.03213
# Epoch: 4, Step: 840, Loss: 2.99212
# Epoch: 4, Step: 850, Loss: 3.16761
# Model saved in file: ./save\model_.ckpt
# Epoch: 5, Step: 500, Loss: 3.31576
# Epoch: 5, Step: 510, Loss: 3.07297
# Epoch: 5, Step: 520, Loss: 3.20025
# Epoch: 5, Step: 530, Loss: 3.00351
# Epoch: 5, Step: 540, Loss: 3.12413
# Epoch: 5, Step: 550, Loss: 3.20275
# Epoch: 5, Step: 560, Loss: 3.00029
# Epoch: 5, Step: 570, Loss: 2.98228
# Epoch: 5, Step: 580, Loss: 2.99457
# Epoch: 5, Step: 590, Loss: 2.95601
# Epoch: 5, Step: 600, Loss: 3.39504
# Epoch: 5, Step: 610, Loss: 3.19497
# Epoch: 5, Step: 620, Loss: 2.95373
# Epoch: 5, Step: 630, Loss: 3.08154
# Epoch: 5, Step: 640, Loss: 2.91167
# Epoch: 5, Step: 650, Loss: 2.94201
# Epoch: 5, Step: 660, Loss: 3.01919
# Epoch: 5, Step: 670, Loss: 3.17704
# Epoch: 5, Step: 680, Loss: 2.90317
# Epoch: 5, Step: 690, Loss: 3.10311
# Epoch: 5, Step: 700, Loss: 2.88832
# Epoch: 5, Step: 710, Loss: 2.78534
# Epoch: 5, Step: 720, Loss: 2.99917
# Epoch: 5, Step: 730, Loss: 2.91863
# Epoch: 5, Step: 740, Loss: 2.95535
# Epoch: 5, Step: 750, Loss: 3.57327
# Epoch: 5, Step: 760, Loss: 2.96997
# Epoch: 5, Step: 770, Loss: 3.09727
# Epoch: 5, Step: 780, Loss: 2.95474
# Epoch: 5, Step: 790, Loss: 2.89201
# Epoch: 5, Step: 800, Loss: 2.86969
# Epoch: 5, Step: 810, Loss: 2.80831
# Epoch: 5, Step: 820, Loss: 2.80295
# Epoch: 5, Step: 830, Loss: 2.81483
# Epoch: 5, Step: 840, Loss: 2.97422
# Epoch: 5, Step: 850, Loss: 2.80021
# Epoch: 5, Step: 860, Loss: 2.84722
# Epoch: 5, Step: 870, Loss: 2.78417
# Epoch: 5, Step: 880, Loss: 3.07741
# Epoch: 5, Step: 890, Loss: 2.93402
# Epoch: 5, Step: 900, Loss: 2.97841
# Epoch: 5, Step: 910, Loss: 2.73476
# Epoch: 5, Step: 920, Loss: 2.80646
# Epoch: 5, Step: 930, Loss: 2.68449
# Epoch: 5, Step: 940, Loss: 2.74385
# Epoch: 5, Step: 950, Loss: 2.8923
# Model saved in file: ./save\model_.ckpt
# Epoch: 6, Step: 600, Loss: 2.92609
# Epoch: 6, Step: 610, Loss: 2.8468
# Epoch: 6, Step: 620, Loss: 2.74644
# Epoch: 6, Step: 630, Loss: 2.78748
# Epoch: 6, Step: 640, Loss: 2.70195
# Epoch: 6, Step: 650, Loss: 3.41082
# Epoch: 6, Step: 660, Loss: 2.64193
# Epoch: 6, Step: 670, Loss: 2.77468
# Epoch: 6, Step: 680, Loss: 2.7965
# Epoch: 6, Step: 690, Loss: 2.82822
# Epoch: 6, Step: 700, Loss: 2.60229
# Epoch: 6, Step: 710, Loss: 2.77766
# Epoch: 6, Step: 720, Loss: 2.67462
# Epoch: 6, Step: 730, Loss: 2.89501
# Epoch: 6, Step: 740, Loss: 3.28235
# Epoch: 6, Step: 750, Loss: 2.7773
# Epoch: 6, Step: 760, Loss: 2.55986
# Epoch: 6, Step: 770, Loss: 2.67772
# Epoch: 6, Step: 780, Loss: 2.57381
# Epoch: 6, Step: 790, Loss: 2.71784
# Epoch: 6, Step: 800, Loss: 2.80554
# Epoch: 6, Step: 810, Loss: 2.59233
# Epoch: 6, Step: 820, Loss: 2.70214
# Epoch: 6, Step: 830, Loss: 2.64962
# Epoch: 6, Step: 840, Loss: 2.61757
# Epoch: 6, Step: 850, Loss: 2.58088
# Epoch: 6, Step: 860, Loss: 2.76771
# Epoch: 6, Step: 870, Loss: 2.70303
# Epoch: 6, Step: 880, Loss: 2.58024
# Epoch: 6, Step: 890, Loss: 2.51126
# Epoch: 6, Step: 900, Loss: 2.70534
# Epoch: 6, Step: 910, Loss: 2.77474
# Epoch: 6, Step: 920, Loss: 2.57305
# Epoch: 6, Step: 930, Loss: 2.58951
# Epoch: 6, Step: 940, Loss: 2.50374
# Epoch: 6, Step: 950, Loss: 2.61648
# Epoch: 6, Step: 960, Loss: 2.48636
# Epoch: 6, Step: 970, Loss: 2.79755
# Epoch: 6, Step: 980, Loss: 2.69295
# Epoch: 6, Step: 990, Loss: 2.4451
# Epoch: 6, Step: 1000, Loss: 2.48983
# Epoch: 6, Step: 1010, Loss: 2.49981
# Epoch: 6, Step: 1020, Loss: 2.50033
# Epoch: 6, Step: 1030, Loss: 2.40378
# Epoch: 6, Step: 1040, Loss: 2.45925
# Epoch: 6, Step: 1050, Loss: 2.4898
# Model saved in file: ./save\model_.ckpt
# Epoch: 7, Step: 700, Loss: 2.61453
# Epoch: 7, Step: 710, Loss: 2.36753
# Epoch: 7, Step: 720, Loss: 2.76285
# Epoch: 7, Step: 730, Loss: 2.48244
# Epoch: 7, Step: 740, Loss: 3.10666
# Epoch: 7, Step: 750, Loss: 2.63764
# Epoch: 7, Step: 760, Loss: 2.88048
# Epoch: 7, Step: 770, Loss: 2.66723
# Epoch: 7, Step: 780, Loss: 2.44719
# Epoch: 7, Step: 790, Loss: 2.57006
# Epoch: 7, Step: 800, Loss: 2.35506
# Epoch: 7, Step: 810, Loss: 2.46867
# Epoch: 7, Step: 820, Loss: 2.62202
# Epoch: 7, Step: 830, Loss: 2.36542
# Epoch: 7, Step: 840, Loss: 2.46686
# Epoch: 7, Step: 850, Loss: 2.48484
# Epoch: 7, Step: 860, Loss: 2.54836
# Epoch: 7, Step: 870, Loss: 2.54829
# Epoch: 7, Step: 880, Loss: 2.53413
# Epoch: 7, Step: 890, Loss: 2.31802
# Epoch: 7, Step: 900, Loss: 2.29365
# Epoch: 7, Step: 910, Loss: 2.52487
# Epoch: 7, Step: 920, Loss: 2.48101
# Epoch: 7, Step: 930, Loss: 2.37694
# Epoch: 7, Step: 940, Loss: 2.37614
# Epoch: 7, Step: 950, Loss: 2.59516
# Epoch: 7, Step: 960, Loss: 2.43391
# Epoch: 7, Step: 970, Loss: 2.29688
# Epoch: 7, Step: 980, Loss: 2.52339
# Epoch: 7, Step: 990, Loss: 2.25953
# Epoch: 7, Step: 1000, Loss: 2.32979
# Epoch: 7, Step: 1010, Loss: 2.34062
# Epoch: 7, Step: 1020, Loss: 2.40945
# Epoch: 7, Step: 1030, Loss: 2.2972
# Epoch: 7, Step: 1040, Loss: 2.44846
# Epoch: 7, Step: 1050, Loss: 2.24968
# Epoch: 7, Step: 1060, Loss: 2.48085
# Epoch: 7, Step: 1070, Loss: 2.41148
# Epoch: 7, Step: 1080, Loss: 2.21928
# Epoch: 7, Step: 1090, Loss: 2.64475
# Epoch: 7, Step: 1100, Loss: 2.32868
# Epoch: 7, Step: 1110, Loss: 2.18982
# Epoch: 7, Step: 1120, Loss: 2.24098
# Epoch: 7, Step: 1130, Loss: 2.32013
# Epoch: 7, Step: 1140, Loss: 2.4375
# Epoch: 7, Step: 1150, Loss: 2.35718
# Model saved in file: ./save\model_.ckpt
# Epoch: 8, Step: 800, Loss: 2.20194
# Epoch: 8, Step: 810, Loss: 2.37892
# Epoch: 8, Step: 820, Loss: 2.29774
# Epoch: 8, Step: 830, Loss: 2.38396
# Epoch: 8, Step: 840, Loss: 2.21887
# Epoch: 8, Step: 850, Loss: 2.20508
# Epoch: 8, Step: 860, Loss: 2.17196
# Epoch: 8, Step: 870, Loss: 2.17837
# Epoch: 8, Step: 880, Loss: 2.42457
# Epoch: 8, Step: 890, Loss: 2.49872
# Epoch: 8, Step: 900, Loss: 2.19269
# Epoch: 8, Step: 910, Loss: 2.16188
# Epoch: 8, Step: 920, Loss: 2.24496
# Epoch: 8, Step: 930, Loss: 2.1579
# Epoch: 8, Step: 940, Loss: 2.05853
# Epoch: 8, Step: 950, Loss: 2.55643
# Epoch: 8, Step: 960, Loss: 2.11024
# Epoch: 8, Step: 970, Loss: 2.22728
# Epoch: 8, Step: 980, Loss: 2.22381
# Epoch: 8, Step: 990, Loss: 2.02509
# Epoch: 8, Step: 1000, Loss: 2.21863
# Epoch: 8, Step: 1010, Loss: 2.15982
# Epoch: 8, Step: 1020, Loss: 2.11005
# Epoch: 8, Step: 1030, Loss: 2.7689
# Epoch: 8, Step: 1040, Loss: 2.25566
# Epoch: 8, Step: 1050, Loss: 2.27992
# Epoch: 8, Step: 1060, Loss: 2.16253
# Epoch: 8, Step: 1070, Loss: 2.16682
# Epoch: 8, Step: 1080, Loss: 2.10966
# Epoch: 8, Step: 1090, Loss: 2.00137
# Epoch: 8, Step: 1100, Loss: 2.0659
# Epoch: 8, Step: 1110, Loss: 2.01443
# Epoch: 8, Step: 1120, Loss: 2.17411
# Epoch: 8, Step: 1130, Loss: 2.0768
# Epoch: 8, Step: 1140, Loss: 2.02284
# Epoch: 8, Step: 1150, Loss: 2.09229
# Epoch: 8, Step: 1160, Loss: 2.3388
# Epoch: 8, Step: 1170, Loss: 2.18261
# Epoch: 8, Step: 1180, Loss: 2.16986
# Epoch: 8, Step: 1190, Loss: 2.00094
# Epoch: 8, Step: 1200, Loss: 1.98308
# Epoch: 8, Step: 1210, Loss: 2.01522
# Epoch: 8, Step: 1220, Loss: 2.00957
# Epoch: 8, Step: 1230, Loss: 1.99355
# Epoch: 8, Step: 1240, Loss: 2.17509
# Epoch: 8, Step: 1250, Loss: 2.12503
# Model saved in file: ./save\model_.ckpt
# Epoch: 9, Step: 900, Loss: 1.97829
# Epoch: 9, Step: 910, Loss: 2.08957
# Epoch: 9, Step: 920, Loss: 1.93334
# Epoch: 9, Step: 930, Loss: 2.6568
# Epoch: 9, Step: 940, Loss: 1.90685
# Epoch: 9, Step: 950, Loss: 2.03175
# Epoch: 9, Step: 960, Loss: 2.0746
# Epoch: 9, Step: 970, Loss: 1.90386
# Epoch: 9, Step: 980, Loss: 2.03209
# Epoch: 9, Step: 990, Loss: 2.0419
# Epoch: 9, Step: 1000, Loss: 1.8698
# Epoch: 9, Step: 1010, Loss: 2.05111
# Epoch: 9, Step: 1020, Loss: 2.56797
# Epoch: 9, Step: 1030, Loss: 2.08218
# Epoch: 9, Step: 1040, Loss: 1.88139
# Epoch: 9, Step: 1050, Loss: 1.92118
# Epoch: 9, Step: 1060, Loss: 1.84773
# Epoch: 9, Step: 1070, Loss: 1.98329
# Epoch: 9, Step: 1080, Loss: 1.93507
# Epoch: 9, Step: 1090, Loss: 1.95712
# Epoch: 9, Step: 1100, Loss: 1.862
# Epoch: 9, Step: 1110, Loss: 1.98509
# Epoch: 9, Step: 1120, Loss: 1.80662
# Epoch: 9, Step: 1130, Loss: 1.93833
# Epoch: 9, Step: 1140, Loss: 1.979
# Epoch: 9, Step: 1150, Loss: 2.00354
# Epoch: 9, Step: 1160, Loss: 1.86889
# Epoch: 9, Step: 1170, Loss: 1.783
# Epoch: 9, Step: 1180, Loss: 1.99423
# Epoch: 9, Step: 1190, Loss: 2.00513
# Epoch: 9, Step: 1200, Loss: 1.87737
# Epoch: 9, Step: 1210, Loss: 1.89635
# Epoch: 9, Step: 1220, Loss: 1.80706
# Epoch: 9, Step: 1230, Loss: 1.86137
# Epoch: 9, Step: 1240, Loss: 1.79238
# Epoch: 9, Step: 1250, Loss: 2.07274
# Epoch: 9, Step: 1260, Loss: 1.95463
# Epoch: 9, Step: 1270, Loss: 1.79922
# Epoch: 9, Step: 1280, Loss: 1.80948
# Epoch: 9, Step: 1290, Loss: 1.77284
# Epoch: 9, Step: 1300, Loss: 1.75652
# Epoch: 9, Step: 1310, Loss: 1.71306
# Epoch: 9, Step: 1320, Loss: 1.7627
# Epoch: 9, Step: 1330, Loss: 1.77683
# Epoch: 9, Step: 1340, Loss: 1.914
# Epoch: 9, Step: 1350, Loss: 1.68085
# Model saved in file: ./save\model_.ckpt
# Epoch: 10, Step: 1000, Loss: 1.97046
# Epoch: 10, Step: 1010, Loss: 1.81851
# Epoch: 10, Step: 1020, Loss: 1.83287
# Epoch: 10, Step: 1030, Loss: 2.4562
# Epoch: 10, Step: 1040, Loss: 2.12509
# Epoch: 10, Step: 1050, Loss: 1.97832
# Epoch: 10, Step: 1060, Loss: 1.74025
# Epoch: 10, Step: 1070, Loss: 1.84398
# Epoch: 10, Step: 1080, Loss: 1.67518
# Epoch: 10, Step: 1090, Loss: 1.79572
# Epoch: 10, Step: 1100, Loss: 1.90876
# Epoch: 10, Step: 1110, Loss: 1.6345
# Epoch: 10, Step: 1120, Loss: 1.76336
# Epoch: 10, Step: 1130, Loss: 1.75527
# Epoch: 10, Step: 1140, Loss: 1.84483
# Epoch: 10, Step: 1150, Loss: 1.76825
# Epoch: 10, Step: 1160, Loss: 1.86234
# Epoch: 10, Step: 1170, Loss: 1.63979
# Epoch: 10, Step: 1180, Loss: 1.61792
# Epoch: 10, Step: 1190, Loss: 1.72178
# Epoch: 10, Step: 1200, Loss: 1.81262
# Epoch: 10, Step: 1210, Loss: 1.63673
# Epoch: 10, Step: 1220, Loss: 1.77298
# Epoch: 10, Step: 1230, Loss: 1.7611
# Epoch: 10, Step: 1240, Loss: 1.89246
# Epoch: 10, Step: 1250, Loss: 1.6325
# Epoch: 10, Step: 1260, Loss: 1.6542
# Epoch: 10, Step: 1270, Loss: 1.69157
# Epoch: 10, Step: 1280, Loss: 1.5994
# Epoch: 10, Step: 1290, Loss: 1.67981
# Epoch: 10, Step: 1300, Loss: 1.6967
# Epoch: 10, Step: 1310, Loss: 1.63101
# Epoch: 10, Step: 1320, Loss: 1.71091
# Epoch: 10, Step: 1330, Loss: 1.60104
# Epoch: 10, Step: 1340, Loss: 1.82428
# Epoch: 10, Step: 1350, Loss: 1.63321
# Epoch: 10, Step: 1360, Loss: 1.6622
# Epoch: 10, Step: 1370, Loss: 1.90488
# Epoch: 10, Step: 1380, Loss: 1.60238
# Epoch: 10, Step: 1390, Loss: 1.55323
# Epoch: 10, Step: 1400, Loss: 1.57219
# Epoch: 10, Step: 1410, Loss: 1.51507
# Epoch: 10, Step: 1420, Loss: 1.69413
# Epoch: 10, Step: 1430, Loss: 1.79538
# Epoch: 10, Step: 1440, Loss: 1.55121
# Epoch: 10, Step: 1450, Loss: 1.69772
# Model saved in file: ./save\model_.ckpt
# Epoch: 11, Step: 1100, Loss: 1.53499
# Epoch: 11, Step: 1110, Loss: 1.69075
# Epoch: 11, Step: 1120, Loss: 1.55547
# Epoch: 11, Step: 1130, Loss: 1.49945
# Epoch: 11, Step: 1140, Loss: 1.51969
# Epoch: 11, Step: 1150, Loss: 1.54109
# Epoch: 11, Step: 1160, Loss: 1.60679
# Epoch: 11, Step: 1170, Loss: 1.83581
# Epoch: 11, Step: 1180, Loss: 1.59033
# Epoch: 11, Step: 1190, Loss: 1.45394
# Epoch: 11, Step: 1200, Loss: 1.62907
# Epoch: 11, Step: 1210, Loss: 1.44029
# Epoch: 11, Step: 1220, Loss: 1.50481
# Epoch: 11, Step: 1230, Loss: 1.78079
# Epoch: 11, Step: 1240, Loss: 1.5857
# Epoch: 11, Step: 1250, Loss: 1.49842
# Epoch: 11, Step: 1260, Loss: 1.54944
# Epoch: 11, Step: 1270, Loss: 1.45161
# Epoch: 11, Step: 1280, Loss: 1.46649
# Epoch: 11, Step: 1290, Loss: 1.64101
# Epoch: 11, Step: 1300, Loss: 1.44969
# Epoch: 11, Step: 1310, Loss: 1.62115
# Epoch: 11, Step: 1320, Loss: 2.06627
# Epoch: 11, Step: 1330, Loss: 1.625
# Epoch: 11, Step: 1340, Loss: 1.53756
# Epoch: 11, Step: 1350, Loss: 1.50501
# Epoch: 11, Step: 1360, Loss: 1.41888
# Epoch: 11, Step: 1370, Loss: 1.46224
# Epoch: 11, Step: 1380, Loss: 1.45852
# Epoch: 11, Step: 1390, Loss: 1.38314
# Epoch: 11, Step: 1400, Loss: 1.51668
# Epoch: 11, Step: 1410, Loss: 1.43876
# Epoch: 11, Step: 1420, Loss: 1.3734
# Epoch: 11, Step: 1430, Loss: 1.51113
# Epoch: 11, Step: 1440, Loss: 1.67418
# Epoch: 11, Step: 1450, Loss: 1.54803
# Epoch: 11, Step: 1460, Loss: 1.44194
# Epoch: 11, Step: 1470, Loss: 1.42194
# Epoch: 11, Step: 1480, Loss: 1.37573
# Epoch: 11, Step: 1490, Loss: 1.4498
# Epoch: 11, Step: 1500, Loss: 1.36228
# Epoch: 11, Step: 1510, Loss: 1.36192
# Epoch: 11, Step: 1520, Loss: 1.5642
# Epoch: 11, Step: 1530, Loss: 1.52511
# Epoch: 11, Step: 1540, Loss: 1.35092
# Epoch: 11, Step: 1550, Loss: 1.4514
# Model saved in file: ./save\model_.ckpt
# Epoch: 12, Step: 1200, Loss: 1.33046
# Epoch: 12, Step: 1210, Loss: 1.90517
# Epoch: 12, Step: 1220, Loss: 1.32703
# Epoch: 12, Step: 1230, Loss: 1.41486
# Epoch: 12, Step: 1240, Loss: 1.4037
# Epoch: 12, Step: 1250, Loss: 1.31614
# Epoch: 12, Step: 1260, Loss: 1.41473
# Epoch: 12, Step: 1270, Loss: 1.41698
# Epoch: 12, Step: 1280, Loss: 1.28829
# Epoch: 12, Step: 1290, Loss: 1.38936
# Epoch: 12, Step: 1300, Loss: 1.86496
# Epoch: 12, Step: 1310, Loss: 1.37275
# Epoch: 12, Step: 1320, Loss: 1.40225
# Epoch: 12, Step: 1330, Loss: 1.30708
# Epoch: 12, Step: 1340, Loss: 1.27577
# Epoch: 12, Step: 1350, Loss: 1.34645
# Epoch: 12, Step: 1360, Loss: 1.33331
# Epoch: 12, Step: 1370, Loss: 1.30748
# Epoch: 12, Step: 1380, Loss: 1.28064
# Epoch: 12, Step: 1390, Loss: 1.39058
# Epoch: 12, Step: 1400, Loss: 1.26273
# Epoch: 12, Step: 1410, Loss: 1.3342
# Epoch: 12, Step: 1420, Loss: 1.30771
# Epoch: 12, Step: 1430, Loss: 1.50108
# Epoch: 12, Step: 1440, Loss: 1.27465
# Epoch: 12, Step: 1450, Loss: 1.22376
# Epoch: 12, Step: 1460, Loss: 1.34794
# Epoch: 12, Step: 1470, Loss: 1.33571
# Epoch: 12, Step: 1480, Loss: 1.39205
# Epoch: 12, Step: 1490, Loss: 1.21103
# Epoch: 12, Step: 1500, Loss: 1.30135
# Epoch: 12, Step: 1510, Loss: 1.18377
# Epoch: 12, Step: 1520, Loss: 1.3329
# Epoch: 12, Step: 1530, Loss: 1.33534
# Epoch: 12, Step: 1540, Loss: 1.31745
# Epoch: 12, Step: 1550, Loss: 1.32776
# Epoch: 12, Step: 1560, Loss: 1.20908
# Epoch: 12, Step: 1570, Loss: 1.25701
# Epoch: 12, Step: 1580, Loss: 1.18848
# Epoch: 12, Step: 1590, Loss: 1.16925
# Epoch: 12, Step: 1600, Loss: 1.19825
# Epoch: 12, Step: 1610, Loss: 1.25163
# Epoch: 12, Step: 1620, Loss: 1.23564
# Epoch: 12, Step: 1630, Loss: 1.20809
# Epoch: 12, Step: 1640, Loss: 1.16007
# Epoch: 12, Step: 1650, Loss: 1.3409
# Model saved in file: ./save\model_.ckpt
# Epoch: 13, Step: 1300, Loss: 1.22482
# Epoch: 13, Step: 1310, Loss: 1.72055
# Epoch: 13, Step: 1320, Loss: 1.38587
# Epoch: 13, Step: 1330, Loss: 1.39499
# Epoch: 13, Step: 1340, Loss: 1.20897
# Epoch: 13, Step: 1350, Loss: 1.23979
# Epoch: 13, Step: 1360, Loss: 1.17098
# Epoch: 13, Step: 1370, Loss: 1.28873
# Epoch: 13, Step: 1380, Loss: 1.24146
# Epoch: 13, Step: 1390, Loss: 1.15595
# Epoch: 13, Step: 1400, Loss: 1.25274
# Epoch: 13, Step: 1410, Loss: 1.16854
# Epoch: 13, Step: 1420, Loss: 1.23242
# Epoch: 13, Step: 1430, Loss: 1.26089
# Epoch: 13, Step: 1440, Loss: 1.23636
# Epoch: 13, Step: 1450, Loss: 1.18475
# Epoch: 13, Step: 1460, Loss: 1.11362
# Epoch: 13, Step: 1470, Loss: 1.13589
# Epoch: 13, Step: 1480, Loss: 1.21369
# Epoch: 13, Step: 1490, Loss: 1.09735
# Epoch: 13, Step: 1500, Loss: 1.19283
# Epoch: 13, Step: 1510, Loss: 1.19303
# Epoch: 13, Step: 1520, Loss: 1.25865
# Epoch: 13, Step: 1530, Loss: 1.13076
# Epoch: 13, Step: 1540, Loss: 1.12141
# Epoch: 13, Step: 1550, Loss: 1.11184
# Epoch: 13, Step: 1560, Loss: 1.08937
# Epoch: 13, Step: 1570, Loss: 1.17521
# Epoch: 13, Step: 1580, Loss: 1.18051
# Epoch: 13, Step: 1590, Loss: 1.09741
# Epoch: 13, Step: 1600, Loss: 1.15311
# Epoch: 13, Step: 1610, Loss: 1.0852
# Epoch: 13, Step: 1620, Loss: 1.27964
# Epoch: 13, Step: 1630, Loss: 1.10257
# Epoch: 13, Step: 1640, Loss: 1.14547
# Epoch: 13, Step: 1650, Loss: 1.14943
# Epoch: 13, Step: 1660, Loss: 1.13292
# Epoch: 13, Step: 1670, Loss: 1.06988
# Epoch: 13, Step: 1680, Loss: 1.06657
# Epoch: 13, Step: 1690, Loss: 1.056
# Epoch: 13, Step: 1700, Loss: 1.07889
# Epoch: 13, Step: 1710, Loss: 1.10638
# Epoch: 13, Step: 1720, Loss: 1.07329
# Epoch: 13, Step: 1730, Loss: 1.16302
# Epoch: 13, Step: 1740, Loss: 1.04674
# Epoch: 13, Step: 1750, Loss: 1.19097
# Model saved in file: ./save\model_.ckpt
# Epoch: 14, Step: 1400, Loss: 1.0768
# Epoch: 14, Step: 1410, Loss: 1.0078
# Epoch: 14, Step: 1420, Loss: 1.02119
# Epoch: 14, Step: 1430, Loss: 1.03659
# Epoch: 14, Step: 1440, Loss: 1.05281
# Epoch: 14, Step: 1450, Loss: 1.15362
# Epoch: 14, Step: 1460, Loss: 1.04072
# Epoch: 14, Step: 1470, Loss: 1.0273
# Epoch: 14, Step: 1480, Loss: 1.06695
# Epoch: 14, Step: 1490, Loss: 0.970167
# Epoch: 14, Step: 1500, Loss: 0.984143
# Epoch: 14, Step: 1510, Loss: 1.12303
# Epoch: 14, Step: 1520, Loss: 1.23126
# Epoch: 14, Step: 1530, Loss: 1.0163
# Epoch: 14, Step: 1540, Loss: 1.05677
# Epoch: 14, Step: 1550, Loss: 0.993796
# Epoch: 14, Step: 1560, Loss: 0.955378
# Epoch: 14, Step: 1570, Loss: 1.09266
# Epoch: 14, Step: 1580, Loss: 0.988195
# Epoch: 14, Step: 1590, Loss: 0.984687
# Epoch: 14, Step: 1600, Loss: 1.33715
# Epoch: 14, Step: 1610, Loss: 0.998192
# Epoch: 14, Step: 1620, Loss: 0.987427
# Epoch: 14, Step: 1630, Loss: 1.03361
# Epoch: 14, Step: 1640, Loss: 0.982053
# Epoch: 14, Step: 1650, Loss: 0.955849
# Epoch: 14, Step: 1660, Loss: 0.994614
# Epoch: 14, Step: 1670, Loss: 0.924512
# Epoch: 14, Step: 1680, Loss: 0.963711
# Epoch: 14, Step: 1690, Loss: 1.04835
# Epoch: 14, Step: 1700, Loss: 0.920795
# Epoch: 14, Step: 1710, Loss: 1.05311
# Epoch: 14, Step: 1720, Loss: 1.10651
# Epoch: 14, Step: 1730, Loss: 1.03229
# Epoch: 14, Step: 1740, Loss: 0.984082
# Epoch: 14, Step: 1750, Loss: 0.952878
# Epoch: 14, Step: 1760, Loss: 0.893762
# Epoch: 14, Step: 1770, Loss: 0.967761
# Epoch: 14, Step: 1780, Loss: 0.92539
# Epoch: 14, Step: 1790, Loss: 0.920639
# Epoch: 14, Step: 1800, Loss: 0.99949
# Epoch: 14, Step: 1810, Loss: 1.01627
# Epoch: 14, Step: 1820, Loss: 0.899519
# Epoch: 14, Step: 1830, Loss: 0.967977
# Epoch: 14, Step: 1840, Loss: 0.897089
# Epoch: 14, Step: 1850, Loss: 1.4912
# Model saved in file: ./save\model_.ckpt
# Epoch: 15, Step: 1500, Loss: 0.896657
# Epoch: 15, Step: 1510, Loss: 0.906862
# Epoch: 15, Step: 1520, Loss: 0.938641
# Epoch: 15, Step: 1530, Loss: 0.916571
# Epoch: 15, Step: 1540, Loss: 0.921383
# Epoch: 15, Step: 1550, Loss: 0.938619
# Epoch: 15, Step: 1560, Loss: 0.891473
# Epoch: 15, Step: 1570, Loss: 0.952938
# Epoch: 15, Step: 1580, Loss: 1.24452
# Epoch: 15, Step: 1590, Loss: 0.900749
# Epoch: 15, Step: 1600, Loss: 1.00344
# Epoch: 15, Step: 1610, Loss: 0.883034
# Epoch: 15, Step: 1620, Loss: 0.862689
# Epoch: 15, Step: 1630, Loss: 0.899144
# Epoch: 15, Step: 1640, Loss: 0.873794
# Epoch: 15, Step: 1650, Loss: 0.886943
# Epoch: 15, Step: 1660, Loss: 0.816401
# Epoch: 15, Step: 1670, Loss: 0.908227
# Epoch: 15, Step: 1680, Loss: 0.836402
# Epoch: 15, Step: 1690, Loss: 0.95726
# Epoch: 15, Step: 1700, Loss: 0.876246
# Epoch: 15, Step: 1710, Loss: 1.05162
# Epoch: 15, Step: 1720, Loss: 0.860868
# Epoch: 15, Step: 1730, Loss: 0.814669
# Epoch: 15, Step: 1740, Loss: 0.848594
# Epoch: 15, Step: 1750, Loss: 0.93013
# Epoch: 15, Step: 1760, Loss: 0.860696
# Epoch: 15, Step: 1770, Loss: 0.810692
# Epoch: 15, Step: 1780, Loss: 0.877326
# Epoch: 15, Step: 1790, Loss: 0.787569
# Epoch: 15, Step: 1800, Loss: 0.859827
# Epoch: 15, Step: 1810, Loss: 0.846307
# Epoch: 15, Step: 1820, Loss: 0.905077
# Epoch: 15, Step: 1830, Loss: 0.894894
# Epoch: 15, Step: 1840, Loss: 0.80217
# Epoch: 15, Step: 1850, Loss: 0.849945
# Epoch: 15, Step: 1860, Loss: 0.801511
# Epoch: 15, Step: 1870, Loss: 0.769236
# Epoch: 15, Step: 1880, Loss: 0.782078
# Epoch: 15, Step: 1890, Loss: 0.821828
# Epoch: 15, Step: 1900, Loss: 0.771087
# Epoch: 15, Step: 1910, Loss: 0.841398
# Epoch: 15, Step: 1920, Loss: 0.763272
# Epoch: 15, Step: 1930, Loss: 0.97804
# Epoch: 15, Step: 1940, Loss: 0.779723
# Epoch: 15, Step: 1950, Loss: 1.24434
# Model saved in file: ./save\model_.ckpt
# Epoch: 16, Step: 1600, Loss: 0.872029
# Epoch: 16, Step: 1610, Loss: 1.1549
# Epoch: 16, Step: 1620, Loss: 0.79824
# Epoch: 16, Step: 1630, Loss: 0.782907
# Epoch: 16, Step: 1640, Loss: 0.779392
# Epoch: 16, Step: 1650, Loss: 0.837436
# Epoch: 16, Step: 1660, Loss: 0.820969
# Epoch: 16, Step: 1670, Loss: 0.761577
# Epoch: 16, Step: 1680, Loss: 0.802255
# Epoch: 16, Step: 1690, Loss: 0.756349
# Epoch: 16, Step: 1700, Loss: 0.77263
# Epoch: 16, Step: 1710, Loss: 0.897093
# Epoch: 16, Step: 1720, Loss: 0.832674
# Epoch: 16, Step: 1730, Loss: 0.791609
# Epoch: 16, Step: 1740, Loss: 0.726944
# Epoch: 16, Step: 1750, Loss: 0.76676
# Epoch: 16, Step: 1760, Loss: 0.764202
# Epoch: 16, Step: 1770, Loss: 0.757713
# Epoch: 16, Step: 1780, Loss: 0.766739
# Epoch: 16, Step: 1790, Loss: 0.792144
# Epoch: 16, Step: 1800, Loss: 0.85341
# Epoch: 16, Step: 1810, Loss: 0.724252
# Epoch: 16, Step: 1820, Loss: 0.72369
# Epoch: 16, Step: 1830, Loss: 0.764481
# Epoch: 16, Step: 1840, Loss: 0.713611
# Epoch: 16, Step: 1850, Loss: 0.706731
# Epoch: 16, Step: 1860, Loss: 0.842882
# Epoch: 16, Step: 1870, Loss: 0.714634
# Epoch: 16, Step: 1880, Loss: 0.76672
# Epoch: 16, Step: 1890, Loss: 0.723759
# Epoch: 16, Step: 1900, Loss: 0.889489
# Epoch: 16, Step: 1910, Loss: 0.719355
# Epoch: 16, Step: 1920, Loss: 0.744579
# Epoch: 16, Step: 1930, Loss: 0.786478
# Epoch: 16, Step: 1940, Loss: 0.747177
# Epoch: 16, Step: 1950, Loss: 0.702018
# Epoch: 16, Step: 1960, Loss: 0.681787
# Epoch: 16, Step: 1970, Loss: 0.701502
# Epoch: 16, Step: 1980, Loss: 0.700854
# Epoch: 16, Step: 1990, Loss: 0.68353
# Epoch: 16, Step: 2000, Loss: 0.699178
# Epoch: 16, Step: 2010, Loss: 0.692683
# Epoch: 16, Step: 2020, Loss: 0.70085
# Epoch: 16, Step: 2030, Loss: 0.75306
# Epoch: 16, Step: 2040, Loss: 0.692321
# Epoch: 16, Step: 2050, Loss: 0.664058
# Model saved in file: ./save\model_.ckpt
# Epoch: 17, Step: 1700, Loss: 0.66653
# Epoch: 17, Step: 1710, Loss: 0.693483
# Epoch: 17, Step: 1720, Loss: 0.672578
# Epoch: 17, Step: 1730, Loss: 0.743528
# Epoch: 17, Step: 1740, Loss: 0.695115
# Epoch: 17, Step: 1750, Loss: 0.687559
# Epoch: 17, Step: 1760, Loss: 0.728183
# Epoch: 17, Step: 1770, Loss: 0.64207
# Epoch: 17, Step: 1780, Loss: 0.640053
# Epoch: 17, Step: 1790, Loss: 0.690935
# Epoch: 17, Step: 1800, Loss: 0.845523
# Epoch: 17, Step: 1810, Loss: 0.643805
# Epoch: 17, Step: 1820, Loss: 0.676364
# Epoch: 17, Step: 1830, Loss: 0.653222
# Epoch: 17, Step: 1840, Loss: 0.61009
# Epoch: 17, Step: 1850, Loss: 0.752547
# Epoch: 17, Step: 1860, Loss: 0.642652
# Epoch: 17, Step: 1870, Loss: 0.645903
# Epoch: 17, Step: 1880, Loss: 0.91875
# Epoch: 17, Step: 1890, Loss: 0.687814
# Epoch: 17, Step: 1900, Loss: 0.670203
# Epoch: 17, Step: 1910, Loss: 0.669516
# Epoch: 17, Step: 1920, Loss: 0.639686
# Epoch: 17, Step: 1930, Loss: 0.626546
# Epoch: 17, Step: 1940, Loss: 0.611743
# Epoch: 17, Step: 1950, Loss: 0.639996
# Epoch: 17, Step: 1960, Loss: 0.617784
# Epoch: 17, Step: 1970, Loss: 0.660749
# Epoch: 17, Step: 1980, Loss: 0.592676
# Epoch: 17, Step: 1990, Loss: 0.649717
# Epoch: 17, Step: 2000, Loss: 0.607093
# Epoch: 17, Step: 2010, Loss: 0.754611
# Epoch: 17, Step: 2020, Loss: 0.638673
# Epoch: 17, Step: 2030, Loss: 0.617695
# Epoch: 17, Step: 2040, Loss: 0.59423
# Epoch: 17, Step: 2050, Loss: 0.65022
# Epoch: 17, Step: 2060, Loss: 0.566471
# Epoch: 17, Step: 2070, Loss: 0.606376
# Epoch: 17, Step: 2080, Loss: 0.614691
# Epoch: 17, Step: 2090, Loss: 0.695337
# Epoch: 17, Step: 2100, Loss: 0.591684
# Epoch: 17, Step: 2110, Loss: 0.652588
# Epoch: 17, Step: 2120, Loss: 0.591443
# Epoch: 17, Step: 2130, Loss: 0.611218
# Epoch: 17, Step: 2140, Loss: 0.693968
# Epoch: 17, Step: 2150, Loss: 0.581623
# Model saved in file: ./save\model_.ckpt
# Epoch: 18, Step: 1800, Loss: 0.607097
# Epoch: 18, Step: 1810, Loss: 0.611058
# Epoch: 18, Step: 1820, Loss: 0.65608
# Epoch: 18, Step: 1830, Loss: 0.555559
# Epoch: 18, Step: 1840, Loss: 0.623676
# Epoch: 18, Step: 1850, Loss: 0.618757
# Epoch: 18, Step: 1860, Loss: 0.665089
# Epoch: 18, Step: 1870, Loss: 0.642234
# Epoch: 18, Step: 1880, Loss: 0.642438
# Epoch: 18, Step: 1890, Loss: 0.548427
# Epoch: 18, Step: 1900, Loss: 0.566165
# Epoch: 18, Step: 1910, Loss: 0.543644
# Epoch: 18, Step: 1920, Loss: 0.613065
# Epoch: 18, Step: 1930, Loss: 0.591349
# Epoch: 18, Step: 1940, Loss: 0.529414
# Epoch: 18, Step: 1950, Loss: 0.584284
# Epoch: 18, Step: 1960, Loss: 0.621128
# Epoch: 18, Step: 1970, Loss: 0.615922
# Epoch: 18, Step: 1980, Loss: 0.534457
# Epoch: 18, Step: 1990, Loss: 0.702102
# Epoch: 18, Step: 2000, Loss: 0.563215
# Epoch: 18, Step: 2010, Loss: 0.537269
# Epoch: 18, Step: 2020, Loss: 0.525059
# Epoch: 18, Step: 2030, Loss: 0.587927
# Epoch: 18, Step: 2040, Loss: 0.548536
# Epoch: 18, Step: 2050, Loss: 0.534079
# Epoch: 18, Step: 2060, Loss: 0.562738
# Epoch: 18, Step: 2070, Loss: 0.512998
# Epoch: 18, Step: 2080, Loss: 0.558712
# Epoch: 18, Step: 2090, Loss: 0.549846
# Epoch: 18, Step: 2100, Loss: 0.646163
# Epoch: 18, Step: 2110, Loss: 0.5804
# Epoch: 18, Step: 2120, Loss: 0.513955
# Epoch: 18, Step: 2130, Loss: 0.589857
# Epoch: 18, Step: 2140, Loss: 0.520447
# Epoch: 18, Step: 2150, Loss: 0.511343
# Epoch: 18, Step: 2160, Loss: 0.503969
# Epoch: 18, Step: 2170, Loss: 0.554577
# Epoch: 18, Step: 2180, Loss: 0.496165
# Epoch: 18, Step: 2190, Loss: 0.579425
# Epoch: 18, Step: 2200, Loss: 0.490859
# Epoch: 18, Step: 2210, Loss: 0.515369
# Epoch: 18, Step: 2220, Loss: 0.541874
# Epoch: 18, Step: 2230, Loss: 0.582183
# Epoch: 18, Step: 2240, Loss: 0.529111
# Epoch: 18, Step: 2250, Loss: 0.495656
# Model saved in file: ./save\model_.ckpt
# Epoch: 19, Step: 1900, Loss: 0.588967
# Epoch: 19, Step: 1910, Loss: 0.539703
# Epoch: 19, Step: 1920, Loss: 0.575368
# Epoch: 19, Step: 1930, Loss: 0.495533
# Epoch: 19, Step: 1940, Loss: 0.584915
# Epoch: 19, Step: 1950, Loss: 0.508157
# Epoch: 19, Step: 1960, Loss: 0.479305
# Epoch: 19, Step: 1970, Loss: 0.503829
# Epoch: 19, Step: 1980, Loss: 0.510239
# Epoch: 19, Step: 1990, Loss: 0.576591
# Epoch: 19, Step: 2000, Loss: 0.631113
# Epoch: 19, Step: 2010, Loss: 0.519201
# Epoch: 19, Step: 2020, Loss: 0.477838
# Epoch: 19, Step: 2030, Loss: 0.469495
# Epoch: 19, Step: 2040, Loss: 0.491235
# Epoch: 19, Step: 2050, Loss: 0.495777
# Epoch: 19, Step: 2060, Loss: 0.483808
# Epoch: 19, Step: 2070, Loss: 0.456811
# Epoch: 19, Step: 2080, Loss: 0.684246
# Epoch: 19, Step: 2090, Loss: 0.472246
# Epoch: 19, Step: 2100, Loss: 0.493735
# Epoch: 19, Step: 2110, Loss: 0.498045
# Epoch: 19, Step: 2120, Loss: 0.449045
# Epoch: 19, Step: 2130, Loss: 0.472175
# Epoch: 19, Step: 2140, Loss: 0.55242
# Epoch: 19, Step: 2150, Loss: 0.527273
# Epoch: 19, Step: 2160, Loss: 0.506962
# Epoch: 19, Step: 2170, Loss: 0.46484
# Epoch: 19, Step: 2180, Loss: 0.554471
# Epoch: 19, Step: 2190, Loss: 0.508279
# Epoch: 19, Step: 2200, Loss: 0.504748
# Epoch: 19, Step: 2210, Loss: 0.45844
# Epoch: 19, Step: 2220, Loss: 0.49105
# Epoch: 19, Step: 2230, Loss: 0.457136
# Epoch: 19, Step: 2240, Loss: 0.434424
# Epoch: 19, Step: 2250, Loss: 0.447348
# Epoch: 19, Step: 2260, Loss: 0.503498
# Epoch: 19, Step: 2270, Loss: 0.447201
# Epoch: 19, Step: 2280, Loss: 0.49401
# Epoch: 19, Step: 2290, Loss: 0.447344
# Epoch: 19, Step: 2300, Loss: 0.452268
# Epoch: 19, Step: 2310, Loss: 0.450483
# Epoch: 19, Step: 2320, Loss: 0.469136
# Epoch: 19, Step: 2330, Loss: 0.426831
# Epoch: 19, Step: 2340, Loss: 0.428289
# Epoch: 19, Step: 2350, Loss: 0.457592
# Model saved in file: ./save\model_.ckpt
# Epoch: 20, Step: 2000, Loss: 0.424129
# Epoch: 20, Step: 2010, Loss: 0.474707
# Epoch: 20, Step: 2020, Loss: 0.470224
# Epoch: 20, Step: 2030, Loss: 0.43012
# Epoch: 20, Step: 2040, Loss: 0.419374
# Epoch: 20, Step: 2050, Loss: 0.475984
# Epoch: 20, Step: 2060, Loss: 0.418807
# Epoch: 20, Step: 2070, Loss: 0.439914
# Epoch: 20, Step: 2080, Loss: 0.591186
# Epoch: 20, Step: 2090, Loss: 0.445954
# Epoch: 20, Step: 2100, Loss: 0.451703
# Epoch: 20, Step: 2110, Loss: 0.445172
# Epoch: 20, Step: 2120, Loss: 0.401057
# Epoch: 20, Step: 2130, Loss: 0.452415
# Epoch: 20, Step: 2140, Loss: 0.456045
# Epoch: 20, Step: 2150, Loss: 0.446325
# Epoch: 20, Step: 2160, Loss: 0.593335
# Epoch: 20, Step: 2170, Loss: 0.4841
# Epoch: 20, Step: 2180, Loss: 0.437301
# Epoch: 20, Step: 2190, Loss: 0.443123
# Epoch: 20, Step: 2200, Loss: 0.43529
# Epoch: 20, Step: 2210, Loss: 0.416623
# Epoch: 20, Step: 2220, Loss: 0.410905
# Epoch: 20, Step: 2230, Loss: 0.435172
# Epoch: 20, Step: 2240, Loss: 0.409997
# Epoch: 20, Step: 2250, Loss: 0.490918
# Epoch: 20, Step: 2260, Loss: 0.392936
# Epoch: 20, Step: 2270, Loss: 0.429094
# Epoch: 20, Step: 2280, Loss: 0.424064
# Epoch: 20, Step: 2290, Loss: 0.459503
# Epoch: 20, Step: 2300, Loss: 0.45476
# Epoch: 20, Step: 2310, Loss: 0.425379
# Epoch: 20, Step: 2320, Loss: 0.394856
# Epoch: 20, Step: 2330, Loss: 0.423669
# Epoch: 20, Step: 2340, Loss: 0.375306
# Epoch: 20, Step: 2350, Loss: 0.410532
# Epoch: 20, Step: 2360, Loss: 0.396431
# Epoch: 20, Step: 2370, Loss: 0.432507
# Epoch: 20, Step: 2380, Loss: 0.519339
# Epoch: 20, Step: 2390, Loss: 0.409119
# Epoch: 20, Step: 2400, Loss: 0.442565
# Epoch: 20, Step: 2410, Loss: 0.395942
# Epoch: 20, Step: 2420, Loss: 0.594042
# Epoch: 20, Step: 2430, Loss: 0.393597
# Epoch: 20, Step: 2440, Loss: 0.405318
# Epoch: 20, Step: 2450, Loss: 0.411801
# Model saved in file: ./save\model_.ckpt
# Epoch: 21, Step: 2100, Loss: 0.440752
# Epoch: 21, Step: 2110, Loss: 0.408676
# Epoch: 21, Step: 2120, Loss: 0.446139
# Epoch: 21, Step: 2130, Loss: 0.389485
# Epoch: 21, Step: 2140, Loss: 0.426855
# Epoch: 21, Step: 2150, Loss: 0.421498
# Epoch: 21, Step: 2160, Loss: 0.457703
# Epoch: 21, Step: 2170, Loss: 0.371975
# Epoch: 21, Step: 2180, Loss: 0.378904
# Epoch: 21, Step: 2190, Loss: 0.379355
# Epoch: 21, Step: 2200, Loss: 0.439267
# Epoch: 21, Step: 2210, Loss: 0.387192
# Epoch: 21, Step: 2220, Loss: 0.371586
# Epoch: 21, Step: 2230, Loss: 0.390977
# Epoch: 21, Step: 2240, Loss: 0.40742
# Epoch: 21, Step: 2250, Loss: 0.396662
# Epoch: 21, Step: 2260, Loss: 0.368703
# Epoch: 21, Step: 2270, Loss: 0.425118
# Epoch: 21, Step: 2280, Loss: 0.39868
# Epoch: 21, Step: 2290, Loss: 0.354044
# Epoch: 21, Step: 2300, Loss: 0.368831
# Epoch: 21, Step: 2310, Loss: 0.391364
# Epoch: 21, Step: 2320, Loss: 0.394676
# Epoch: 21, Step: 2330, Loss: 0.360048
# Epoch: 21, Step: 2340, Loss: 0.39216
# Epoch: 21, Step: 2350, Loss: 0.36958
# Epoch: 21, Step: 2360, Loss: 0.394984
# Epoch: 21, Step: 2370, Loss: 0.359547
# Epoch: 21, Step: 2380, Loss: 0.436785
# Epoch: 21, Step: 2390, Loss: 0.469212
# Epoch: 21, Step: 2400, Loss: 0.388454
# Epoch: 21, Step: 2410, Loss: 0.401776
# Epoch: 21, Step: 2420, Loss: 0.340012
# Epoch: 21, Step: 2430, Loss: 0.343774
# Epoch: 21, Step: 2440, Loss: 0.333
# Epoch: 21, Step: 2450, Loss: 0.345081
# Epoch: 21, Step: 2460, Loss: 0.371739
# Epoch: 21, Step: 2470, Loss: 0.41059
# Epoch: 21, Step: 2480, Loss: 0.332787
# Epoch: 21, Step: 2490, Loss: 0.367436
# Epoch: 21, Step: 2500, Loss: 0.366071
# Epoch: 21, Step: 2510, Loss: 0.448262
# Epoch: 21, Step: 2520, Loss: 0.384343
# Epoch: 21, Step: 2530, Loss: 0.731375
# Epoch: 21, Step: 2540, Loss: 0.488381
# Epoch: 21, Step: 2550, Loss: 0.387129
# Model saved in file: ./save\model_.ckpt
# Epoch: 22, Step: 2200, Loss: 0.390005
# Epoch: 22, Step: 2210, Loss: 0.344125
# Epoch: 22, Step: 2220, Loss: 0.392099
# Epoch: 22, Step: 2230, Loss: 0.405693
# Epoch: 22, Step: 2240, Loss: 0.332676
# Epoch: 22, Step: 2250, Loss: 0.339914
# Epoch: 22, Step: 2260, Loss: 0.391284
# Epoch: 22, Step: 2270, Loss: 0.427685
# Epoch: 22, Step: 2280, Loss: 0.391349
# Epoch: 22, Step: 2290, Loss: 0.406758
# Epoch: 22, Step: 2300, Loss: 0.33169
# Epoch: 22, Step: 2310, Loss: 0.331275
# Epoch: 22, Step: 2320, Loss: 0.371416
# Epoch: 22, Step: 2330, Loss: 0.388787
# Epoch: 22, Step: 2340, Loss: 0.344227
# Epoch: 22, Step: 2350, Loss: 0.330686
# Epoch: 22, Step: 2360, Loss: 0.477795
# Epoch: 22, Step: 2370, Loss: 0.347711
# Epoch: 22, Step: 2380, Loss: 0.329296
# Epoch: 22, Step: 2390, Loss: 0.369973
# Epoch: 22, Step: 2400, Loss: 0.3174
# Epoch: 22, Step: 2410, Loss: 0.327233
# Epoch: 22, Step: 2420, Loss: 0.369788
# Epoch: 22, Step: 2430, Loss: 0.376263
# Epoch: 22, Step: 2440, Loss: 0.343402
# Epoch: 22, Step: 2450, Loss: 0.364423
# Epoch: 22, Step: 2460, Loss: 0.316068
# Epoch: 22, Step: 2470, Loss: 0.438025
# Epoch: 22, Step: 2480, Loss: 0.379965
# Epoch: 22, Step: 2490, Loss: 0.330082
# Epoch: 22, Step: 2500, Loss: 0.367404
# Epoch: 22, Step: 2510, Loss: 0.32575
# Epoch: 22, Step: 2520, Loss: 0.324821
# Epoch: 22, Step: 2530, Loss: 0.324684
# Epoch: 22, Step: 2540, Loss: 0.334134
# Epoch: 22, Step: 2550, Loss: 0.333076
# Epoch: 22, Step: 2560, Loss: 0.355045
# Epoch: 22, Step: 2570, Loss: 0.314675
# Epoch: 22, Step: 2580, Loss: 0.327652
# Epoch: 22, Step: 2590, Loss: 0.318094
# Epoch: 22, Step: 2600, Loss: 0.335334
# Epoch: 22, Step: 2610, Loss: 0.306889
# Epoch: 22, Step: 2620, Loss: 0.301158
# Epoch: 22, Step: 2630, Loss: 0.327356
# Epoch: 22, Step: 2640, Loss: 0.323137
# Epoch: 22, Step: 2650, Loss: 0.333093
# Model saved in file: ./save\model_.ckpt
# Epoch: 23, Step: 2300, Loss: 0.354113
# Epoch: 23, Step: 2310, Loss: 0.362154
# Epoch: 23, Step: 2320, Loss: 0.323899
# Epoch: 23, Step: 2330, Loss: 0.305909
# Epoch: 23, Step: 2340, Loss: 0.294126
# Epoch: 23, Step: 2350, Loss: 0.305819
# Epoch: 23, Step: 2360, Loss: 0.449687
# Epoch: 23, Step: 2370, Loss: 0.303897
# Epoch: 23, Step: 2380, Loss: 0.329265
# Epoch: 23, Step: 2390, Loss: 0.344174
# Epoch: 23, Step: 2400, Loss: 0.298127
# Epoch: 23, Step: 2410, Loss: 0.323168
# Epoch: 23, Step: 2420, Loss: 0.323998
# Epoch: 23, Step: 2430, Loss: 0.314329
# Epoch: 23, Step: 2440, Loss: 0.415848
# Epoch: 23, Step: 2450, Loss: 0.343939
# Epoch: 23, Step: 2460, Loss: 0.372567
# Epoch: 23, Step: 2470, Loss: 0.315853
# Epoch: 23, Step: 2480, Loss: 0.345492
# Epoch: 23, Step: 2490, Loss: 0.30211
# Epoch: 23, Step: 2500, Loss: 0.289291
# Epoch: 23, Step: 2510, Loss: 0.333301
# Epoch: 23, Step: 2520, Loss: 0.292481
# Epoch: 23, Step: 2530, Loss: 0.34582
# Epoch: 23, Step: 2540, Loss: 0.330527
# Epoch: 23, Step: 2550, Loss: 0.311165
# Epoch: 23, Step: 2560, Loss: 0.343931
# Epoch: 23, Step: 2570, Loss: 0.360378
# Epoch: 23, Step: 2580, Loss: 0.358357
# Epoch: 23, Step: 2590, Loss: 0.309434
# Epoch: 23, Step: 2600, Loss: 0.303976
# Epoch: 23, Step: 2610, Loss: 0.307093
# Epoch: 23, Step: 2620, Loss: 0.309467
# Epoch: 23, Step: 2630, Loss: 0.344267
# Epoch: 23, Step: 2640, Loss: 0.295615
# Epoch: 23, Step: 2650, Loss: 0.337523
# Epoch: 23, Step: 2660, Loss: 0.355328
# Epoch: 23, Step: 2670, Loss: 0.301743
# Epoch: 23, Step: 2680, Loss: 0.347181
# Epoch: 23, Step: 2690, Loss: 0.283915
# Epoch: 23, Step: 2700, Loss: 0.430816
# Epoch: 23, Step: 2710, Loss: 0.285891
# Epoch: 23, Step: 2720, Loss: 0.287517
# Epoch: 23, Step: 2730, Loss: 0.30608
# Epoch: 23, Step: 2740, Loss: 0.314339
# Epoch: 23, Step: 2750, Loss: 0.292915
# Model saved in file: ./save\model_.ckpt
# Epoch: 24, Step: 2400, Loss: 0.323057
# Epoch: 24, Step: 2410, Loss: 0.281921
# Epoch: 24, Step: 2420, Loss: 0.320864
# Epoch: 24, Step: 2430, Loss: 0.332671
# Epoch: 24, Step: 2440, Loss: 0.375103
# Epoch: 24, Step: 2450, Loss: 0.286191
# Epoch: 24, Step: 2460, Loss: 0.280648
# Epoch: 24, Step: 2470, Loss: 0.26738
# Epoch: 24, Step: 2480, Loss: 0.35639
# Epoch: 24, Step: 2490, Loss: 0.328576
# Epoch: 24, Step: 2500, Loss: 0.293509
# Epoch: 24, Step: 2510, Loss: 0.281087
# Epoch: 24, Step: 2520, Loss: 0.37405
# Epoch: 24, Step: 2530, Loss: 0.276679
# Epoch: 24, Step: 2540, Loss: 0.316837
# Epoch: 24, Step: 2550, Loss: 0.333364
# Epoch: 24, Step: 2560, Loss: 0.31889
# Epoch: 24, Step: 2570, Loss: 0.282127
# Epoch: 24, Step: 2580, Loss: 0.269545
# Epoch: 24, Step: 2590, Loss: 0.311662
# Epoch: 24, Step: 2600, Loss: 0.319131
# Epoch: 24, Step: 2610, Loss: 0.318273
# Epoch: 24, Step: 2620, Loss: 0.289365
# Epoch: 24, Step: 2630, Loss: 0.282144
# Epoch: 24, Step: 2640, Loss: 0.275823
# Epoch: 24, Step: 2650, Loss: 0.280055
# Epoch: 24, Step: 2660, Loss: 0.371264
# Epoch: 24, Step: 2670, Loss: 0.268668
# Epoch: 24, Step: 2680, Loss: 0.298228
# Epoch: 24, Step: 2690, Loss: 0.280113
# Epoch: 24, Step: 2700, Loss: 0.323023
# Epoch: 24, Step: 2710, Loss: 0.26994
# Epoch: 24, Step: 2720, Loss: 0.258694
# Epoch: 24, Step: 2730, Loss: 0.261113
# Epoch: 24, Step: 2740, Loss: 0.281482
# Epoch: 24, Step: 2750, Loss: 0.316157
# Epoch: 24, Step: 2760, Loss: 0.258923
# Epoch: 24, Step: 2770, Loss: 0.322796
# Epoch: 24, Step: 2780, Loss: 0.309516
# Epoch: 24, Step: 2790, Loss: 0.277386
# Epoch: 24, Step: 2800, Loss: 0.35523
# Epoch: 24, Step: 2810, Loss: 0.288771
# Epoch: 24, Step: 2820, Loss: 0.337729
# Epoch: 24, Step: 2830, Loss: 0.299721
# Epoch: 24, Step: 2840, Loss: 0.306592
# Epoch: 24, Step: 2850, Loss: 0.259156
# Model saved in file: ./save\model_.ckpt
# Epoch: 25, Step: 2500, Loss: 0.328823
# Epoch: 25, Step: 2510, Loss: 0.340865
# Epoch: 25, Step: 2520, Loss: 0.25841
# Epoch: 25, Step: 2530, Loss: 0.278661
# Epoch: 25, Step: 2540, Loss: 0.280539
# Epoch: 25, Step: 2550, Loss: 0.352184
# Epoch: 25, Step: 2560, Loss: 0.327557
# Epoch: 25, Step: 2570, Loss: 0.328455
# Epoch: 25, Step: 2580, Loss: 0.271913
# Epoch: 25, Step: 2590, Loss: 0.252297
# Epoch: 25, Step: 2600, Loss: 0.264265
# Epoch: 25, Step: 2610, Loss: 0.29924
# Epoch: 25, Step: 2620, Loss: 0.26259
# Epoch: 25, Step: 2630, Loss: 0.320321
# Epoch: 25, Step: 2640, Loss: 0.279211
# Epoch: 25, Step: 2650, Loss: 0.359596
# Epoch: 25, Step: 2660, Loss: 0.259781
# Epoch: 25, Step: 2670, Loss: 0.293377
# Epoch: 25, Step: 2680, Loss: 0.25714
# Epoch: 25, Step: 2690, Loss: 0.255853
# Epoch: 25, Step: 2700, Loss: 0.288481
# Epoch: 25, Step: 2710, Loss: 0.313538
# Epoch: 25, Step: 2720, Loss: 0.257928
# Epoch: 25, Step: 2730, Loss: 0.274739
# Epoch: 25, Step: 2740, Loss: 0.270858
# Epoch: 25, Step: 2750, Loss: 0.395863
# Epoch: 25, Step: 2760, Loss: 0.258067
# Epoch: 25, Step: 2770, Loss: 0.295579
# Epoch: 25, Step: 2780, Loss: 0.31081
# Epoch: 25, Step: 2790, Loss: 0.306335
# Epoch: 25, Step: 2800, Loss: 0.268311
# Epoch: 25, Step: 2810, Loss: 0.265367
# Epoch: 25, Step: 2820, Loss: 0.269773
# Epoch: 25, Step: 2830, Loss: 0.258249
# Epoch: 25, Step: 2840, Loss: 0.266116
# Epoch: 25, Step: 2850, Loss: 0.269811
# Epoch: 25, Step: 2860, Loss: 0.302695
# Epoch: 25, Step: 2870, Loss: 0.239072
# Epoch: 25, Step: 2880, Loss: 0.266753
# Epoch: 25, Step: 2890, Loss: 0.259289
# Epoch: 25, Step: 2900, Loss: 0.266811
# Epoch: 25, Step: 2910, Loss: 0.254538
# Epoch: 25, Step: 2920, Loss: 0.257814
# Epoch: 25, Step: 2930, Loss: 0.2663
# Epoch: 25, Step: 2940, Loss: 0.34403
# Epoch: 25, Step: 2950, Loss: 0.290044
# Model saved in file: ./save\model_.ckpt
# Epoch: 26, Step: 2600, Loss: 0.242769
# Epoch: 26, Step: 2610, Loss: 0.258297
# Epoch: 26, Step: 2620, Loss: 0.240556
# Epoch: 26, Step: 2630, Loss: 0.259009
# Epoch: 26, Step: 2640, Loss: 0.312663
# Epoch: 26, Step: 2650, Loss: 0.28127
# Epoch: 26, Step: 2660, Loss: 0.274485
# Epoch: 26, Step: 2670, Loss: 0.263305
# Epoch: 26, Step: 2680, Loss: 0.252577
# Epoch: 26, Step: 2690, Loss: 0.247766
# Epoch: 26, Step: 2700, Loss: 0.304043
# Epoch: 26, Step: 2710, Loss: 0.27764
# Epoch: 26, Step: 2720, Loss: 0.275277
# Epoch: 26, Step: 2730, Loss: 0.38611
# Epoch: 26, Step: 2740, Loss: 0.278524
# Epoch: 26, Step: 2750, Loss: 0.246481
# Epoch: 26, Step: 2760, Loss: 0.286937
# Epoch: 26, Step: 2770, Loss: 0.246916
# Epoch: 26, Step: 2780, Loss: 0.262872
# Epoch: 26, Step: 2790, Loss: 0.268862
# Epoch: 26, Step: 2800, Loss: 0.228506
# Epoch: 26, Step: 2810, Loss: 0.259356
# Epoch: 26, Step: 2820, Loss: 0.28191
# Epoch: 26, Step: 2830, Loss: 0.235258
# Epoch: 26, Step: 2840, Loss: 0.280386
# Epoch: 26, Step: 2850, Loss: 0.267289
# Epoch: 26, Step: 2860, Loss: 0.32634
# Epoch: 26, Step: 2870, Loss: 0.245521
# Epoch: 26, Step: 2880, Loss: 0.252809
# Epoch: 26, Step: 2890, Loss: 0.244
# Epoch: 26, Step: 2900, Loss: 0.251399
# Epoch: 26, Step: 2910, Loss: 0.247877
# Epoch: 26, Step: 2920, Loss: 0.254034
# Epoch: 26, Step: 2930, Loss: 0.255548
# Epoch: 26, Step: 2940, Loss: 0.302315
# Epoch: 26, Step: 2950, Loss: 0.244824
# Epoch: 26, Step: 2960, Loss: 0.26584
# Epoch: 26, Step: 2970, Loss: 0.241463
# Epoch: 26, Step: 2980, Loss: 0.280005
# Epoch: 26, Step: 2990, Loss: 0.231373
# Epoch: 26, Step: 3000, Loss: 0.249482
# Epoch: 26, Step: 3010, Loss: 0.257035
# Epoch: 26, Step: 3020, Loss: 0.29611
# Epoch: 26, Step: 3030, Loss: 0.242394
# Epoch: 26, Step: 3040, Loss: 0.270355
# Epoch: 26, Step: 3050, Loss: 0.235986
# Model saved in file: ./save\model_.ckpt
# Epoch: 27, Step: 2700, Loss: 0.243688
# Epoch: 27, Step: 2710, Loss: 0.261567
# Epoch: 27, Step: 2720, Loss: 0.259712
# Epoch: 27, Step: 2730, Loss: 0.376399
# Epoch: 27, Step: 2740, Loss: 0.236842
# Epoch: 27, Step: 2750, Loss: 0.234478
# Epoch: 27, Step: 2760, Loss: 0.338559
# Epoch: 27, Step: 2770, Loss: 0.327413
# Epoch: 27, Step: 2780, Loss: 0.298255
# Epoch: 27, Step: 2790, Loss: 0.238179
# Epoch: 27, Step: 2800, Loss: 0.287753
# Epoch: 27, Step: 2810, Loss: 0.238326
# Epoch: 27, Step: 2820, Loss: 0.267084
# Epoch: 27, Step: 2830, Loss: 0.247649
# Epoch: 27, Step: 2840, Loss: 0.309415
# Epoch: 27, Step: 2850, Loss: 0.239533
# Epoch: 27, Step: 2860, Loss: 0.230469
# Epoch: 27, Step: 2870, Loss: 0.269057
# Epoch: 27, Step: 2880, Loss: 0.261116
# Epoch: 27, Step: 2890, Loss: 0.280317
# Epoch: 27, Step: 2900, Loss: 0.23247
# Epoch: 27, Step: 2910, Loss: 0.257864
# Epoch: 27, Step: 2920, Loss: 0.21665
# Epoch: 27, Step: 2930, Loss: 0.253431
# Epoch: 27, Step: 2940, Loss: 0.285271
# Epoch: 27, Step: 2950, Loss: 0.262005
# Epoch: 27, Step: 2960, Loss: 0.246928
# Epoch: 27, Step: 2970, Loss: 0.246549
# Epoch: 27, Step: 2980, Loss: 0.285233
# Epoch: 27, Step: 2990, Loss: 0.23263
# Epoch: 27, Step: 3000, Loss: 0.222555
# Epoch: 27, Step: 3010, Loss: 0.231921
# Epoch: 27, Step: 3020, Loss: 0.278543
# Epoch: 27, Step: 3030, Loss: 0.234287
# Epoch: 27, Step: 3040, Loss: 0.243813
# Epoch: 27, Step: 3050, Loss: 0.220526
# Epoch: 27, Step: 3060, Loss: 0.260108
# Epoch: 27, Step: 3070, Loss: 0.225561
# Epoch: 27, Step: 3080, Loss: 0.451506
# Epoch: 27, Step: 3090, Loss: 0.286414
# Epoch: 27, Step: 3100, Loss: 0.318017
# Epoch: 27, Step: 3110, Loss: 0.251196
# Epoch: 27, Step: 3120, Loss: 0.265518
# Epoch: 27, Step: 3130, Loss: 0.242572
# Epoch: 27, Step: 3140, Loss: 0.257256
# Epoch: 27, Step: 3150, Loss: 0.241671
# Model saved in file: ./save\model_.ckpt
# Epoch: 28, Step: 2800, Loss: 0.221769
# Epoch: 28, Step: 2810, Loss: 0.231051
# Epoch: 28, Step: 2820, Loss: 0.229932
# Epoch: 28, Step: 2830, Loss: 0.277448
# Epoch: 28, Step: 2840, Loss: 0.278318
# Epoch: 28, Step: 2850, Loss: 0.281542
# Epoch: 28, Step: 2860, Loss: 0.250373
# Epoch: 28, Step: 2870, Loss: 0.22587
# Epoch: 28, Step: 2880, Loss: 0.231346
# Epoch: 28, Step: 2890, Loss: 0.241973
# Epoch: 28, Step: 2900, Loss: 0.232528
# Epoch: 28, Step: 2910, Loss: 0.256877
# Epoch: 28, Step: 2920, Loss: 0.260285
# Epoch: 28, Step: 2930, Loss: 0.308206
# Epoch: 28, Step: 2940, Loss: 0.22131
# Epoch: 28, Step: 2950, Loss: 0.23137
# Epoch: 28, Step: 2960, Loss: 0.234558
# Epoch: 28, Step: 2970, Loss: 0.227222
# Epoch: 28, Step: 2980, Loss: 0.285317
# Epoch: 28, Step: 2990, Loss: 0.247672
# Epoch: 28, Step: 3000, Loss: 0.227611
# Epoch: 28, Step: 3010, Loss: 0.253533
# Epoch: 28, Step: 3020, Loss: 0.233669
# Epoch: 28, Step: 3030, Loss: 0.378225
# Epoch: 28, Step: 3040, Loss: 0.232003
# Epoch: 28, Step: 3050, Loss: 0.270579
# Epoch: 28, Step: 3060, Loss: 0.273664
# Epoch: 28, Step: 3070, Loss: 0.284457
# Epoch: 28, Step: 3080, Loss: 0.227022
# Epoch: 28, Step: 3090, Loss: 0.218308
# Epoch: 28, Step: 3100, Loss: 0.221637
# Epoch: 28, Step: 3110, Loss: 0.231093
# Epoch: 28, Step: 3120, Loss: 0.221182
# Epoch: 28, Step: 3130, Loss: 0.229028
# Epoch: 28, Step: 3140, Loss: 0.280058
# Epoch: 28, Step: 3150, Loss: 0.212511
# Epoch: 28, Step: 3160, Loss: 0.229792
# Epoch: 28, Step: 3170, Loss: 0.229158
# Epoch: 28, Step: 3180, Loss: 0.223429
# Epoch: 28, Step: 3190, Loss: 0.222374
# Epoch: 28, Step: 3200, Loss: 0.232181
# Epoch: 28, Step: 3210, Loss: 0.219031
# Epoch: 28, Step: 3220, Loss: 0.325448
# Epoch: 28, Step: 3230, Loss: 0.228704
# Epoch: 28, Step: 3240, Loss: 0.219784
# Epoch: 28, Step: 3250, Loss: 0.249308
# Model saved in file: ./save\model_.ckpt
# Epoch: 29, Step: 2900, Loss: 0.214017
# Epoch: 29, Step: 2910, Loss: 0.248228
# Epoch: 29, Step: 2920, Loss: 0.233669
# Epoch: 29, Step: 2930, Loss: 0.302619
# Epoch: 29, Step: 2940, Loss: 0.258626
# Epoch: 29, Step: 2950, Loss: 0.381339
# Epoch: 29, Step: 2960, Loss: 0.245071
# Epoch: 29, Step: 2970, Loss: 0.207826
# Epoch: 29, Step: 2980, Loss: 0.37012
# Epoch: 29, Step: 2990, Loss: 0.235635
# Epoch: 29, Step: 3000, Loss: 0.245595
# Epoch: 29, Step: 3010, Loss: 0.712574
# Epoch: 29, Step: 3020, Loss: 0.248585
# Epoch: 29, Step: 3030, Loss: 0.267718
# Epoch: 29, Step: 3040, Loss: 0.259542
# Epoch: 29, Step: 3050, Loss: 0.22832
# Epoch: 29, Step: 3060, Loss: 0.211922
# Epoch: 29, Step: 3070, Loss: 0.241565
# Epoch: 29, Step: 3080, Loss: 0.206759
# Epoch: 29, Step: 3090, Loss: 0.206404
# Epoch: 29, Step: 3100, Loss: 0.302236
# Epoch: 29, Step: 3110, Loss: 0.207623
# Epoch: 29, Step: 3120, Loss: 0.243488
# Epoch: 29, Step: 3130, Loss: 0.333587
# Epoch: 29, Step: 3140, Loss: 0.286195
# Epoch: 29, Step: 3150, Loss: 0.235458
# Epoch: 29, Step: 3160, Loss: 0.213484
# Epoch: 29, Step: 3170, Loss: 0.205403
# Epoch: 29, Step: 3180, Loss: 0.237785
# Epoch: 29, Step: 3190, Loss: 0.199426
# Epoch: 29, Step: 3200, Loss: 0.259322
# Epoch: 29, Step: 3210, Loss: 0.218564
# Epoch: 29, Step: 3220, Loss: 0.28352
# Epoch: 29, Step: 3230, Loss: 0.223908
# Epoch: 29, Step: 3240, Loss: 0.246888
# Epoch: 29, Step: 3250, Loss: 0.210309
# Epoch: 29, Step: 3260, Loss: 0.230201
# Epoch: 29, Step: 3270, Loss: 0.283505
# Epoch: 29, Step: 3280, Loss: 0.212688
# Epoch: 29, Step: 3290, Loss: 0.268186
# Epoch: 29, Step: 3300, Loss: 0.21607
# Epoch: 29, Step: 3310, Loss: 0.273113
# Epoch: 29, Step: 3320, Loss: 0.222906
# Epoch: 29, Step: 3330, Loss: 0.247806
# Epoch: 29, Step: 3340, Loss: 0.250666
# Epoch: 29, Step: 3350, Loss: 0.333447
# Model saved in file: ./save\model_.ckpt
# Run the command line:
# --> tensorboard --logdir=./logs
# Then open http://0.0.0.0:6006/ into your web browser

# %% [markdown]
# <h2>Run through Images and make predictions</h2>

# %%
import tensorflow as tf
import scipy.misc 
import model
import cv2
from subprocess import call

sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, "save/model.ckpt")

img = cv2.imread('steering_wheel_image.jpg',0)
rows,cols = img.shape

smoothed_angle = 0

cap = cv2.VideoCapture(0)
while(cv2.waitKey(10) != ord('q')):
    ret, frame = cap.read()
    image = scipy.misc.imresize(frame, [66, 200]) / 255.0
    degrees = model.y.eval(feed_dict={model.x: [image], model.keep_prob: 0.5})[0][0] * 180 / scipy.pi
    call("clear")
    print("Predicted steering angle: " + str(degrees) + " degrees")
    cv2.imshow('frame', frame)
    #make smooth angle transitions by turning the steering wheel based on the difference of the current angle
    #and the predicted angle
    smoothed_angle += 0.2 * pow(abs((degrees - smoothed_angle)), 2.0 / 3.0) * (degrees - smoothed_angle) / abs(degrees - smoothed_angle)
    M = cv2.getRotationMatrix2D((cols/2,rows/2),-smoothed_angle,1)
    dst = cv2.warpAffine(img,M,(cols,rows))
    cv2.imshow("steering wheel", dst)

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# <h1>Run the run_dataset.py python file to visualize the result</h1>

# %%
#This is run_dataset.py. Run this file to visualize the result.

import tensorflow as tf
import scipy.misc
import model
import cv2
from subprocess import call
import math

sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, "save/model.ckpt")

img = cv2.imread('steering_wheel_image.jpg',0)
rows,cols = img.shape

smoothed_angle = 0


#read data.txt
xs = []
ys = []
with open("driving_dataset/data.txt") as f:
    for line in f:
        xs.append("driving_dataset/" + line.split()[0])
        #the paper by Nvidia uses the inverse of the turning radius,
        #but steering wheel angle is proportional to the inverse of turning radius
        #so the steering wheel angle in radians is used as the output
        ys.append(float(line.split()[1]) * scipy.pi / 180)

#get number of images
num_images = len(xs)


i = math.ceil(num_images*0.7)
print("Starting frameofvideo:" +str(i))

while(cv2.waitKey(10) != ord('q')):
    full_image = scipy.misc.imread("driving_dataset/" + str(i) + ".jpg", mode="RGB")
    image = scipy.misc.imresize(full_image[-150:], [66, 200]) / 255.0
    degrees = model.y.eval(feed_dict={model.x: [image], model.keep_prob: 1.0})[0][0] * 180.0 / scipy.pi
    #call("clear")
    #print("Predicted Steering angle: " + str(degrees))
    print("Steering angle: " + str(degrees) + " (pred)\t" + str(ys[i]*180/scipy.pi) + " (actual)")
    cv2.imshow("frame", cv2.cvtColor(full_image, cv2.COLOR_RGB2BGR))
    #make smooth angle transitions by turning the steering wheel based on the difference of the current angle
    #and the predicted angle
    smoothed_angle += 0.2 * pow(abs((degrees - smoothed_angle)), 2.0 / 3.0) * (degrees - smoothed_angle) / abs(degrees - smoothed_angle)
    M = cv2.getRotationMatrix2D((cols/2,rows/2),-smoothed_angle,1)
    dst = cv2.warpAffine(img,M,(cols,rows))
    cv2.imshow("steering wheel", dst)
    i += 1

cv2.destroyAllWindows()
